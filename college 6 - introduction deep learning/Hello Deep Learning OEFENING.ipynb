# %% [markdown]
# # Introduction Deep Learning   -- OEFENING --
#
# - Voorbeeld deep learning
# - Oefening

# %% [markdown]
# ## Hello Deep Learning (tensorflow2)
#
# tutorial: https://www.tensorflow.org/tutorials/quickstart/beginner
#
# In deze korte introductie wordt `Keras` gebruikt om:
#
# - een neuraal netwerk te bouwen dat afbeeldingen classificeert.
# - dit neurale netwerk te trainen.
# - En ten slotte, de nauwkeurigheid van het model te evalueren.
#
# **Preconditie**: installeer `tensorflow` (versie 2 inclusief `keras`) in terminal/console-programma `Anaconda Prompt` met commando `conda install tensorflow`.
#
# - **Windows**: open `Anaconda Prompt` via Start menu, type in het genoemde commando.
# ![image.png](attachment:image.png)
# </br>**Experimenteel**: als je een Nvidia GPU hebt, kun je de berekingen een beetje versnellen: `conda install tensorflow-gpu`.
# - **MacOS / Linux**: via Terminal / iTerm, type in `conda install tensorflow`.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# TODO: importeer TensorFlow en print de versie (moet 2.* zijn!)
# Out:
# Tensorflow version: 2.0.0

# %%
# specificeer de mnist dataset
mnist = tf........         # TODO

# TODO: inladen de mnist dataset en maak een training set (data en labels)
# en een test set (data en labels)

# schaal de training en testdata: 
#     /255 is de data te converteren van uint8 naar float32 in bereik [0,1].
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# **Opmerking:** het downloaden van de MNIST data op regel 3 van URL https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz kan `download permissie` nodig hebben van de computer.

# %% [markdown]
# **TODO**
# Bouw het `tf.keras.Sequential` model door lagen te stapelen. Kies een optimalisatie- en verliesfunctie voor training:

# %%
model = ....

model.compile(optimizer=....,   # optimalisatie algorithm
              loss=....,
              metrics=....)     # streven naar de beste nauwkeurigheid

# %% [markdown]
# Train en evalueer het model:

# %%
model.fit(.... , epochs=5)
print('-'*40)
model.evaluate(...., verbose=2)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 11s 190us/sample - loss: 0.3001 - accuracy: 0.9115
# Epoch 2/5
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.1454 - accuracy: 0.9562
# Epoch 3/5
# 60000/60000 [==============================] - 10s 171us/sample - loss: 0.1100 - accuracy: 0.9668
# Epoch 4/5
# 60000/60000 [==============================] - 10s 171us/sample - loss: 0.0903 - accuracy: 0.9715
# Epoch 5/5
# 60000/60000 [==============================] - 11s 176us/sample - loss: 0.0751 - accuracy: 0.9765
# ----------------------------------------
# 10000/1 - 1s - loss: 0.0400 - accuracy: 0.9757
# [0.0788133935987018, 0.9757]

# %% [markdown]
# De `image classifier` is nu getraind tot ~98% nauwkeurigheid op deze dataset.

# %% [markdown]
# ## --------- Optioneel ---------

# %% [markdown]
# zie Jupyter notebook **Hello Deep Learning** in College 6.

# %% [markdown]
# ## Oefening - doe dit later!
#
# Klassificeer beelden van kleding: tutorial op https://www.tensorflow.org/tutorials/keras/classification
#
# De `Fashion MNIST` dataset bevat 70.000 grijswaardenafbeeldingen in 10 categorieën. De afbeeldingen tonen afzonderlijke kledingartikelen met een lage resolutie (28 bij 28 pixels), zoals hier is te zien:
# ![Fashion clothing](images/fashion-mnist-sprite.png)

# %% [markdown]
# ---
# ## Bronnen
#
# - **[Gordan]** *Introduction To TensorFlow 2.0*, presentation by Josh Gordon, TF World '19, https://youtu.be/9pHCch_d9hE, gezien op 2019-1202
# - **[tensorflow2]** Lees de tutorials van TensorFlow voor meer informatie: https://www.tensorflow.org/tutorials/, gezien op 2019-1202.
#
#
# #### Bekijk ook de volgende bronnen
#
# - **[GreerViau]** Youtube: Neural Network Learns to Play Snake, https://youtu.be/zIkBYwdkuTk, gezien op 2019-1202
# - **[SamuelArzt]** Youtube: AI Learns to Park - Deep Reinforcement Learning, https://youtu.be/VMp6pq6_QjI, gezien op 2019-1202
